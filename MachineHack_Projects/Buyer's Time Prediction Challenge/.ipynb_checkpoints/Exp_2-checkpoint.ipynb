# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import mean_squared_log_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("Data\Train.csv",
                parse_dates=["date"])
df.head()
# Out:
#                          session_id  session_number  \
# 0  57f879e70d3c5fc2a98102d64c9fd84e             715
# 1  a5442b0c7c33d0a811e7661e556b2de8              55
# 2  305cb1486ed8610c00b37007926cb2c4              11
# 3  f2c1ecc9993f0071df91ba178450498c            2794
# 4  e460830ae295e55d2216ebdc761ab9a6            3674
#
#                                         client_agent      device_details  \
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...    Desktop - Chrome
# 1                           Product/8.0 iPhone/8.1.3        iPhone - iOS
# 2  Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like ...  iPhone - MobileWeb
# 3  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...        Desktop - IE
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_1 like ...        iPhone - Web
#
#         date  purchased  added_in_cart  checked_out  time_spent
# 0 2020-01-22          1              0            0     236.886
# 1 2020-02-27          1              0            0    1277.455
# 2 2019-08-01          0              0            0      21.704
# 3 2019-12-30          0              1            0     455.201
# 4 2019-09-10          0              0            0    1164.877

# %%
df["log_time_spent"] = np.log(df["time_spent"])
df["log_time_spent"].hist()
# Out:
# <AxesSubplot:>

# %%
df['sum_ac_pr_co']=df['added_in_cart']+df['purchased']+df['checked_out']

# %%
df.head(2)
# Out:
#                          session_id  session_number  \
# 0  57f879e70d3c5fc2a98102d64c9fd84e             715
# 1  a5442b0c7c33d0a811e7661e556b2de8              55
#
#                                         client_agent    device_details  \
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  Desktop - Chrome
# 1                           Product/8.0 iPhone/8.1.3      iPhone - iOS
#
#         date  purchased  added_in_cart  checked_out  time_spent  \
# 0 2020-01-22          1              0            0     236.886
# 1 2020-02-27          1              0            0    1277.455
#
#    log_time_spent  sum_ac_pr_co
# 0        5.467579             1
# 1        7.152625             1

# %%
df.device_details.unique()
# Out:
# array(['Desktop - Chrome', 'iPhone - iOS', 'iPhone - MobileWeb',
#        'Desktop - IE', 'iPhone - Web', 'Android Phone - Android',
#        'Desktop - Firefox', 'Android Tablet - Web', 'iPad - Web',
#        'Other - Other', 'Desktop - Safari', 'Android Phone - Web',
#        'iPad - iOS', 'Android Phone - MobileWeb', 'Unknown - MobileWeb',
#        'Android Tablet - Android', 'Android Tablet - MobileWeb'],
#       dtype=object)

# %%
def grouping_device(data):
    print(f"data passed as ==> {data}")
    if "Desktop" in data:
        data = "desktop"
    elif "Phone" in data or "Tablet" in data or "iPad" in data or "Mobile" in data:
        data = "phone"
    else:
        data = "Other"
    print(f"data converted as ==> {data}")
    return data
    
df["device_details"] = df["device_details"].apply(lambda x: grouping_device(x))
# Out:
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPad - iOS
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPad - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPad - iOS
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Android Phone - MobileWeb
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Android Phone - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPad - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPad - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Phone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPad - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Tablet - Android
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - MobileWeb
# data converted as ==> phone
# data passed as ==> Android Phone - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPad - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Phone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# ...
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPad - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPad - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPad - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPad - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Other - Other
# data converted as ==> Other
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPad - Web
# data converted as ==> phone
# data passed as ==> iPhone - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> Desktop - Firefox
# data converted as ==> desktop
# data passed as ==> Android Phone - Web
# data converted as ==> phone
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Desktop - IE
# data converted as ==> desktop
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Safari
# data converted as ==> desktop
# data passed as ==> Android Tablet - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Android Phone - Android
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone
# data passed as ==> iPhone - iOS
# data converted as ==> phone
# data passed as ==> Desktop - Chrome
# data converted as ==> desktop
# data passed as ==> Unknown - MobileWeb
# data converted as ==> phone
# data passed as ==> iPhone - Web
# data converted as ==> phone

# %%
df["device_details"].unique()
# Out:
# array(['desktop', 'phone', 'Other'], dtype=object)

# %%
df[["client_agent", "device_details", "date"]]
# Out:
#                                            client_agent device_details  \
# 0     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...        desktop
# 1                              Product/8.0 iPhone/8.1.3          phone
# 2     Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like ...          phone
# 3     Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...        desktop
# 4     Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_1 like ...          phone
# ...                                                 ...            ...
# 5424  Mozilla/5.0 (iPhone; CPU iPhone OS 8_1 like Ma...          phone
# 5425                         Product/4.2.2 iPhone/7.1.1          phone
# 5426  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4)...        desktop
# 5427                                                NaN          phone
# 5428  Mozilla/5.0 (iPhone; CPU iPhone OS 7_0_4 like ...          phone
#
#            date
# 0    2020-01-22
# 1    2020-02-27
# 2    2019-08-01
# 3    2019-12-30
# 4    2019-09-10
# ...         ...
# 5424 2019-11-20
# 5425 2019-09-26
# 5426 2019-08-13
# 5427 2019-06-18
# 5428 2019-10-21
#
# [5429 rows x 3 columns]

# %%
def grouping_client_agent(df):
    for val in df["client_agent"].values:
        print (val)
        if "Mozilla" in val:
            val1 = "mozilla"
        elif "Product" in val:
            val1 = "browser"
        else:
            val1 = "other"   
        
        for val2 in df["device_details"]:
            val_f = val1+"_"+val2
            print(val_f)  
    
    return df

grouping_client_agent(df[11:12])
# Out:
# Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Mobile/11D257 [FBAN/MessengerForiOS;FBAV/9.1.0.15.14;FBBV/3594432;FBDV/iPhone5,2;FBMD/iPhone;FBSN/iPhone OS;FBSV/7.1.2;FBSS/2; FBCR/Telstra;FBID/phone;FBLC/en_US;FBOP/5]
# mozilla_phone
#                           session_id  session_number  \
# 11  6dbdb72ff887577f72c5e2931b5902e4              22
#
#                                          client_agent device_details  \
# 11  Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like ...          phone
#
#          date  purchased  added_in_cart  checked_out  time_spent  \
# 11 2019-08-27          0              0            0     111.788
#
#     log_time_spent  sum_ac_pr_co
# 11        4.716604             0

# %%
for val in df["client_agent"][11:12].values:
    print (val)
# Out:
# Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Mobile/11D257 [FBAN/MessengerForiOS;FBAV/9.1.0.15.14;FBBV/3594432;FBDV/iPhone5,2;FBMD/iPhone;FBSN/iPhone OS;FBSV/7.1.2;FBSS/2; FBCR/Telstra;FBID/phone;FBLC/en_US;FBOP/5]

# %%
df[11:12]
# Out:
#                           session_id  session_number  \
# 11  6dbdb72ff887577f72c5e2931b5902e4              22
#
#                                          client_agent device_details  \
# 11  Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like ...          phone
#
#          date  purchased  added_in_cart  checked_out  time_spent  \
# 11 2019-08-27          0              0            0     111.788
#
#     log_time_spent  sum_ac_pr_co
# 11        4.716604             0
